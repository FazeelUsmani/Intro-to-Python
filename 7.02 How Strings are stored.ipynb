# %% [markdown]
# ### Strings are immutable in Python

# %%
s = "fazeel"

# %%
s[0] = "Z"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-ab16af40fadd> in <module>
# ----> 1 s[0] = "Z"
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# #### The above example shows how strings are immutable, you cannot change the character at particular index

# %%
id(s)
# Out:
# 2185906125936

# %%
print(s)
# Out:
# fazeel

# %%
a = "Usmani"

# %%
id(a)
# Out:
# 2185906831688

# %%
print(a)
# Out:
# Usmani

# %%
a = "fazeel"

# %%
id(a)
# Out:
# 2185906125936

# %%
s = "Usmani"

# %%
id(s)
# Out:
# 2185906834600

# %%
id(a)
# Out:
# 2185906125936

# %%
s="abcd"
s[0]='c'
print(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-1be48fe55b0b> in <module>
#       1 s="abcd"
# ----> 2 s[0]='c'
#       3 print(s)
#
# TypeError: 'str' object does not support item assignment

# %%
s = "abcd"
a = "abcd"
if id(s) == id(a):
    print("They are same")
else:
    print("They are not same")
# Out:
# They are same
