# %% [markdown]
# 1
# 11
# 202
# 3003
# 40004

# %%
n = int(input())
i = 1
while i <= n:
    j = 1
    while j <= i:
        print(0, end = '')
        j = j+1    
    print()
    i = i + 1
# Out:
# 5
# 0
# 00
# 000
# 0000
# 00000

# %% [markdown]
# 1
# 11
# 202
# 3003
# 40004
# 500005

# %%
n = int(input())
i = 1
while i <= n:
    j = 1
    while j <= i:
        if i==1 and j==i:
            print(1, end = '')
        elif j == 1:
            print(j+i-2, end = '')
        elif j == i:
            print(j-1, end = '')
        else:
            print(0, end = '')
        j = j + 1
    print()
    i = i + 1
# Out:
# 10
# 1
# 11
# 202
# 3003
# 40004
# 500005
# 6000006
# 70000007
# 800000008
# 9000000009

# %% [markdown]
# 1
# 11
# 121
# 1221
# 12221
# 122221

# %%
n = int(input())
i = 1
while i <= n:
    j = 1
    while j <= i:
        if i==1 and j==i:
            print(1, end = '')
        elif j == 1 or j == i:
            print(1, end = '')
        else:
            print(2, end = '')
        j = j + 1
    print()
    i = i + 1
# Out:
# 5
# 1
# 11
# 121
# 1221
# 12221

# %% [markdown]
# 1234
# 123
# 12
# 1

# %%
n = int(input())
i = 0
while i <= n:
    j = 1
    temp = 1
    while j <= n - i:
        print(temp, end ='')
        j = j + 1
        temp = temp + 1
    print()
    i = i + 1
# Out:
# 10
# 12345678910
# 123456789
# 12345678
# 1234567
# 123456
# 12345
# 1234
# 123
# 12
# 1

# %% [markdown]
# A
# BB
# CCC
# DDDD
# EEEEE
# FFFFFF
# GGGGGGG

# %%
n = int(input())
i = 1
while i <= n:
    j = 1
    while j <= i:
        print(chr(ord('A') + i - 1), end = "")        
        j = j + 1
    print()
    i = i + 1
# Out:
# 4
# A
# BB
# CCC
# DDDD

# %%
A
AB
ABC
ABCD

# %%
n = int(input())
i = 1
while i <= n:
    j = 1
    while j <= i:
        print(chr(ord('A') + j - 1), end = "")        
        j = j + 1
    print()
    i = i + 1
